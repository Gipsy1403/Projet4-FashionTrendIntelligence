# %%
import os
import requests
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
import base64
import io
from dotenv import load_dotenv

# %%
# TODO: Modifiez ces valeurs selon votre configuration
image_dir = "asset/top_influenceurs_2024/IMG"  # Exemple : si vous êtes sur Colab et avez uploadé un dossier
max_images = 3  # Commençons avec peu d'images

# IMPORTANT: Remplacez "VOTRE_TOKEN_HUGGING_FACE_ICI" par votre véritable token API.
# Ne partagez jamais votre token publiquement.
# api_token = "VOTRE_TOKEN_HUGGING_FACE_ICI"
load_dotenv()
api_token = os.getenv("HUGGINGFACE_API_TOKEN")

# Créons le dossier d'images s'il n'existe pas (pour l'exemple)
if not os.path.exists(image_dir):
    os.makedirs(image_dir)
    print(f"Dossier '{image_dir}' créé. Veuillez y ajouter des images .jpg ou .png.")
else:
    print(f"Dossier '{image_dir}' existant.")

if api_token == "VOTRE_TOKEN_HUGGING_FACE_ICI":
    print("\nATTENTION : Vous devez remplacer 'VOTRE_TOKEN_HUGGING_FACE_ICI' par votre token API personnel.")
# Out:
# Dossier 'asset/top_influenceurs_2024/IMG' existant.

# %%
API_URL = "https://api-inference.huggingface.co/models/sayeed99/segformer_b3_clothes" # Remplacez ... par le bon endpoint.
headers = {
    "Authorization": f"Bearer {api_token}"
    # Le "Content-Type" sera ajouté dynamiquement lors de l'envoi de l'image
}

# Lister les chemins des images à traiter
# Assurez-vous d'avoir des images dans le dossier 'image_dir'!
image_paths = [
    os.path.join(image_dir, f)
    for f in os.listdir(image_dir)
    if f.lower().endswith((".png", ".jpg", ".jpeg"))
] # A vous de jouer !


if not image_paths:
    print(f"Aucune image trouvée dans '{image_dir}'. Veuillez y ajouter des images.")
else:
    print(f"{len(image_paths)} image(s) à traiter : {image_paths}")
# Out:
# 50 image(s) à traiter : ['asset/top_influenceurs_2024/IMG\\image_0.png', 'asset/top_influenceurs_2024/IMG\\image_1.png', 'asset/top_influenceurs_2024/IMG\\image_10.png', 'asset/top_influenceurs_2024/IMG\\image_11.png', 'asset/top_influenceurs_2024/IMG\\image_12.png', 'asset/top_influenceurs_2024/IMG\\image_13.png', 'asset/top_influenceurs_2024/IMG\\image_14.png', 'asset/top_influenceurs_2024/IMG\\image_15.png', 'asset/top_influenceurs_2024/IMG\\image_16.png', 'asset/top_influenceurs_2024/IMG\\image_17.png', 'asset/top_influenceurs_2024/IMG\\image_18.png', 'asset/top_influenceurs_2024/IMG\\image_19.png', 'asset/top_influenceurs_2024/IMG\\image_2.png', 'asset/top_influenceurs_2024/IMG\\image_20.png', 'asset/top_influenceurs_2024/IMG\\image_21.png', 'asset/top_influenceurs_2024/IMG\\image_22.png', 'asset/top_influenceurs_2024/IMG\\image_23.png', 'asset/top_influenceurs_2024/IMG\\image_24.png', 'asset/top_influenceurs_2024/IMG\\image_25.png', 'asset/top_influenceurs_2024/IMG\\image_26.png', 'asset/top_influenceurs_2024/IMG\\image_27.png', 'asset/top_influenceurs_2024/IMG\\image_28.png', 'asset/top_influenceurs_2024/IMG\\image_29.png', 'asset/top_influenceurs_2024/IMG\\image_3.png', 'asset/top_influenceurs_2024/IMG\\image_30.png', 'asset/top_influenceurs_2024/IMG\\image_31.png', 'asset/top_influenceurs_2024/IMG\\image_32.png', 'asset/top_influenceurs_2024/IMG\\image_33.png', 'asset/top_influenceurs_2024/IMG\\image_34.png', 'asset/top_influenceurs_2024/IMG\\image_35.png', 'asset/top_influenceurs_2024/IMG\\image_36.png', 'asset/top_influenceurs_2024/IMG\\image_37.png', 'asset/top_influenceurs_2024/IMG\\image_38.png', 'asset/top_influenceurs_2024/IMG\\image_39.png', 'asset/top_influenceurs_2024/IMG\\image_4.png', 'asset/top_influenceurs_2024/IMG\\image_40.png', 'asset/top_influenceurs_2024/IMG\\image_41.png', 'asset/top_influenceurs_2024/IMG\\image_42.png', 'asset/top_influenceurs_2024/IMG\\image_43.png', 'asset/top_influenceurs_2024/IMG\\image_44.png', 'asset/top_influenceurs_2024/IMG\\image_45.png', 'asset/top_influenceurs_2024/IMG\\image_46.png', 'asset/top_influenceurs_2024/IMG\\image_47.png', 'asset/top_influenceurs_2024/IMG\\image_48.png', 'asset/top_influenceurs_2024/IMG\\image_49.png', 'asset/top_influenceurs_2024/IMG\\image_5.png', 'asset/top_influenceurs_2024/IMG\\image_6.png', 'asset/top_influenceurs_2024/IMG\\image_7.png', 'asset/top_influenceurs_2024/IMG\\image_8.png', 'asset/top_influenceurs_2024/IMG\\image_9.png']

# %%
# dico class_mapping
CLASS_MAPPING = {
    "Background": 0,
    "Hat": 1,
    "Hair": 2,
    "Sunglasses": 3,
    "Upper-clothes": 4,
    "Skirt": 5,
    "Pants": 6,
    "Dress": 7,
    "Belt": 8,
    "Left-shoe": 9,
    "Right-shoe": 10,
    "Face": 11,
    "Left-leg": 12,
    "Right-leg": 13,
    "Left-arm": 14,
    "Right-arm": 15,
    "Bag": 16,
    "Scarf": 17
}
# fonction permettant de connaitre les dimensions de l'image originale
def get_image_dimensions(img_path):
    """
    Get the dimensions of an image.

    Args:
        img_path (str): Path to the image.

    Returns:
        tuple: (width, height) of the image.
    """
    original_image = Image.open(img_path)
    return original_image.size

# function permettant de décoder l'image originale en chaine base64(0 à 255), de convertir et de redimensionner le masque à la taille de l'image original
def decode_base64_mask(base64_string, width, height):
    """
    Decode a base64-encoded mask into a NumPy array.

    Args:
        base64_string (str): Base64-encoded mask.
        width (int): Target width.
        height (int): Target height.

    Returns:
        np.ndarray: Single-channel mask array.
    """
    mask_data = base64.b64decode(base64_string)
    mask_image = Image.open(io.BytesIO(mask_data))
    mask_array = np.array(mask_image)
    if len(mask_array.shape) == 3:
        mask_array = mask_array[:, :, 0]  # Take first channel if RGB
    mask_image = Image.fromarray(mask_array).resize((width, height), Image.NEAREST)
    return np.array(mask_image)
# la fonction décode le mask, récupère l'ID via Class-mapping et remplit les zones où le mask est supérieur à 0 (fusionne tous les mask en une seule image de segmentation)
def create_masks(results, width, height):
    """
    Combine multiple class masks into a single segmentation mask.

    Args:
        results (list): List of dictionaries with 'label' and 'mask' keys.
        width (int): Target width.
        height (int): Target height.

    Returns:
        np.ndarray: Combined segmentation mask with class indices.
    """
    combined_mask = np.zeros((height, width), dtype=np.uint8)  # Initialize with Background (0)

    # Process non-Background masks first
    for result in results:
        label = result['label']
        class_id = CLASS_MAPPING.get(label, 0)
        if class_id == 0:  # Skip Background
            continue
        mask_array = decode_base64_mask(result['mask'], width, height)
        combined_mask[mask_array > 0] = class_id

    # Process Background last to ensure it doesn't overwrite other classes unnecessarily
    # (Though the model usually provides non-overlapping masks for distinct classes other than background)
    for result in results:
        if result['label'] == 'Background':
            mask_array = decode_base64_mask(result['mask'], width, height)
            # Apply background only where no other class has been assigned yet
            # This logic might need adjustment based on how the model defines 'Background'
            # For this model, it seems safer to just let non-background overwrite it first.
            # A simple application like this should be fine: if Background mask says pixel is BG, set it to 0.
            # However, a more robust way might be to only set to background if combined_mask is still 0 (initial value)
            combined_mask[mask_array > 0] = 0 # Class ID for Background is 0

    return combined_mask

# %%
if image_paths:
    single_image_path = image_paths[0] # Prenons la première image de notre liste
    print(f"Traitement de l'image : {single_image_path}")

    try:
        # Lire l'image en binaire
        # Et mettez le contenu de l'image dans la variable image_data
        # image_data = None # A vous de jouer !
        with open(single_image_path, "rb") as f:
            image_data = f.read()

        # Maintenant, utilisé l'API huggingface
        # ainsi que les fonctions données plus haut pour ségmenter vos images.
        response = requests.post(API_URL, headers=headers, data=image_data)
        # Vérifier la réponse
        response.raise_for_status()
        #converti la réponse json en dico python
        results=response.json()
        print(results)
        # récupère les dimensions de l'image
        width, height = get_image_dimensions(single_image_path)
        print(f"Dimensions de l'image : {width}x{height}")
        # crée le masque combiné à partir des résultats
        combined_mask = create_masks(results, width, height)

        # Affichage côte à côte
        fig, ax = plt.subplots(1, 2, figsize=(10, 5))
        
        # Image originale
        ax[0].imshow(Image.open(single_image_path))
        ax[0].set_title("Image originale")
        
        # Masque de segmentation
        ax[1].imshow(combined_mask)
        ax[1].set_title("Masque de segmentation")
        
        plt.show()

    except Exception as e:
        print(f"Une erreur est survenue : {e}")
else:
    print("Aucune image à traiter. Vérifiez la configuration de 'image_dir' et 'max_images'.")
# Out:
# Traitement de l'image : asset/top_influenceurs_2024/IMG\image_0.png
# Une erreur est survenue : 400 Client Error: Bad Request for url: https://api-inference.huggingface.co/models/sayeed99/segformer_b3_clothes
